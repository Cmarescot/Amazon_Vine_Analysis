# %%
# Import Pandas
import pandas as pd

# %%
# Create datatframe from imported csv
vine_table_df = pd.read_csv("../../vine_table.csv")
vine_table_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 0        R14LVB34Z2Z53I          5.0            0.0          0.0    N
# 1        R2M0R9CWPC82LT          5.0            0.0          0.0    N
# 2         RQNQI2R3BM52A          4.0            0.0          0.0    N
# 3         RTUIX1135HUAB          5.0            0.0          0.0    N
# 4         RE3QSAT8TL010          4.0            0.0          0.0    N
# ...                 ...          ...            ...          ...  ...
# 1688879   RPJVPR5A5XRAN          5.0            0.0          0.0    N
# 1688880   R1497N35CA1J5          5.0            0.0          0.0    N
# 1688881   RA1QA65MLJA0S          4.0            0.0          0.0    N
# 1688882  R1AUDY2ED3Q1YT          5.0            0.0          0.0    N
# 1688883  R3ODJG7TQK43XZ          5.0            0.0          0.0    N
#
#         verified_purchase
# 0                       Y
# 1                       Y
# 2                       Y
# ...

# %%
# create a new DataFrame or table to retrieve all the rows where the total_votes count is equal to or greater than 20
helpful_reviews = vine_table_df.loc[vine_table_df["total_votes"] >= 20]
helpful_reviews
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 319      R1S0N56H5B9SUX          5.0           30.0         30.0    N
# 5683      RCDI7Z8VCZJI9          4.0           40.0         43.0    N
# 6081     R3F4225VTUO2WE          1.0            8.0         33.0    N
# 8753       R3ADPNURCCTK          1.0            1.0         39.0    N
# 9260     R2LWBYC8TEUVF2          5.0           50.0         53.0    N
# ...                 ...          ...            ...          ...  ...
# 1688700  R1BSIOAJTD472E          2.0           10.0         37.0    N
# 1688733  R1O9L27PR8CYMN          5.0           24.0         28.0    N
# 1688736  R1T8JUDC5PFE89          3.0            3.0         27.0    N
# 1688803  R2SXH801UXVMUT          3.0            1.0         24.0    N
# 1688830  R1ZG6Y8ELQ7CYS          1.0            4.0         31.0    N
#
#         verified_purchase
# 319                     Y
# 5683                    N
# 6081                    N
# ...

# %%
# create a new DataFrame or table to retrieve all the rows where the number of helpful_votes divided by total_votes is equal to or greater than 50%.
helpful_reviews_2 = helpful_reviews.loc[(helpful_reviews["helpful_votes"]/ helpful_reviews["total_votes"])>= .50]
helpful_reviews_2
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 319      R1S0N56H5B9SUX          5.0           30.0         30.0    N
# 5683      RCDI7Z8VCZJI9          4.0           40.0         43.0    N
# 9260     R2LWBYC8TEUVF2          5.0           50.0         53.0    N
# 9508     R23E4EIJXID5IC          5.0           43.0         43.0    N
# 10064    R1WFSWDT8L5RSJ          4.0           23.0         26.0    N
# ...                 ...          ...            ...          ...  ...
# 1688463  R29XFIQHBRZI5M          5.0           19.0         20.0    N
# 1688654   R37GT7I6AFE9E          5.0           15.0         21.0    N
# 1688668  R2L1OTCLWU32OP          5.0           22.0         26.0    N
# 1688697  R2C9ZB6UN5S4IU          5.0           57.0         58.0    N
# 1688733  R1O9L27PR8CYMN          5.0           24.0         28.0    N
#
#         verified_purchase
# 319                     Y
# 5683                    N
# 9260                    Y
# ...

# %%
# create a new DataFrame or table that retrieves all the rows where a review was written as part of the Vine program (paid)
paid_reviews = helpful_reviews_2.loc[helpful_reviews_2["vine"] == "Y"]
paid_reviews
# Out:
# Empty DataFrame
# Columns: [review_id, star_rating, helpful_votes, total_votes, vine, verified_purchase]
# Index: []

# %%
# Total number of paid reviews 
number_paid = paid_reviews.count()
number_paid
# Out:
# review_id            0
# star_rating          0
# helpful_votes        0
# total_votes          0
# vine                 0
# verified_purchase    0
# dtype: int64

# %%
# Number of 5 star reviews (paid)
paid_5_stars = paid_reviews.loc[paid_reviews["star_rating"] == 5.0].count()
paid_5_stars
# Out:
# review_id            0
# star_rating          0
# helpful_votes        0
# total_votes          0
# vine                 0
# verified_purchase    0
# dtype: int64

# %%
# Percentage of 5 star reviews(paid)
# Percentage of 5 star reviews(unpaid)
percentage_5_star_paid = (paid_5_stars/number_paid)* 100
percentage_5_star_paid
# Out:
# review_id           NaN
# star_rating         NaN
# helpful_votes       NaN
# total_votes         NaN
# vine                NaN
# verified_purchase   NaN
# dtype: float64

# %%
# retrieve all the rows where the review was not part of the Vine program (unpaid)
unpaid_reviews = helpful_reviews_2.loc[helpful_reviews_2["vine"] == "N"]
unpaid_reviews
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 319      R1S0N56H5B9SUX          5.0           30.0         30.0    N
# 5683      RCDI7Z8VCZJI9          4.0           40.0         43.0    N
# 9260     R2LWBYC8TEUVF2          5.0           50.0         53.0    N
# 9508     R23E4EIJXID5IC          5.0           43.0         43.0    N
# 10064    R1WFSWDT8L5RSJ          4.0           23.0         26.0    N
# ...                 ...          ...            ...          ...  ...
# 1688463  R29XFIQHBRZI5M          5.0           19.0         20.0    N
# 1688654   R37GT7I6AFE9E          5.0           15.0         21.0    N
# 1688668  R2L1OTCLWU32OP          5.0           22.0         26.0    N
# 1688697  R2C9ZB6UN5S4IU          5.0           57.0         58.0    N
# 1688733  R1O9L27PR8CYMN          5.0           24.0         28.0    N
#
#         verified_purchase
# 319                     Y
# 5683                    N
# 9260                    Y
# ...

# %%
# Total number of unpaid reviews 
number_unpaid = unpaid_reviews.count()
number_unpaid
# Out:
# review_id            4532
# star_rating          4532
# helpful_votes        4532
# total_votes          4532
# vine                 4532
# verified_purchase    4532
# dtype: int64

# %%
# Number of 5 star reviews (unpaid)
unpaid_5_stars = unpaid_reviews.loc[unpaid_reviews["star_rating"] == 5.0].count()
unpaid_5_stars
# Out:
# review_id            2507
# star_rating          2507
# helpful_votes        2507
# total_votes          2507
# vine                 2507
# verified_purchase    2507
# dtype: int64

# %%
# Percentage of 5 star reviews(unpaid)
percentage_5_star = (unpaid_5_stars/number_unpaid)* 100
percentage_5_star
# Out:
# review_id            55.317741
# star_rating          55.317741
# helpful_votes        55.317741
# total_votes          55.317741
# vine                 55.317741
# verified_purchase    55.317741
# dtype: float64
